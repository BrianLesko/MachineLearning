# %% [markdown]
# # Lab: SVMs on Extended MNIST
#
# In the demo for this unit, we saw how SVMs can be used for the classic problem of MNIST digit recognition. In this lab, we are going to extend the MNIST dataset by adding a number of non-digit letters and see if the classifier can distinguish the digits from the non-digits. All non-digits will be lumped as a single 11-th class. This is a highly simplified version of a 'detection' problem (as opposed to 'classification' problem). Detection is vital in OCR and related problems since the non useful characters must be rejected.
#
# In addition to the concepts in the demo, you will learn:
# * Combine multiple datasets
# * Select the SVM parameters (`C` and `gamma`) via cross-validation.
# * Use the `GridSearchCV` method to search for parameters with cross-validation.

# %% [markdown]
# As usual, we download the standard packages

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model, preprocessing

# %% [markdown]
# ## About NIST, National Institute of Standards and Technology
# NIST is an agency of the United States Department of Commerce that promotes innovation and industrial competitiveness by advancing measurement science, standards, and technology. NIST also develops cybersecurity resources for various sectors and applications.

# %% [markdown]
# ## Downloading the EMNIST Dataset
#
# After creating the highly popular MNIST dataset, NIST created an extended version of the dataset that includes letters and digits.
# The extended datbase (called EMNIST) also has many more examples per class.
#
# To download the data, go to the [EMNIST webpage](https://www.nist.gov/itl/iad/image-group/emnist-dataset).  Near the bottom, you will see a link for `MATLAB format dataset`.  If you click on this link, you will download a `zip` file with several datasets in it.  The total file is 726M, so it may take some time and diskspace to download.  Extract two files:
# * `emnist-digits.mat`:  This is a file of digits `0` to `9`, but with more examples per class.
# * `emnist-letters.mat`:  This is a file of letters `a/A` to `z/Z`.  The lower and upper case letters are grouped into the same class.
#
# Once you get these two files, you can save yourself the diskspace and remove all the other files.

# %%
# TODO:  Download emnist-letters.mat and emnist-digits.mat to the working directory

# %% [markdown]
# Since MATLAB files are still widely-used, Python has excellent routines for loading MATLAB files.  The function below uses the `scipy.io` package to extract the relevant fields from the MATLAB file.  Specifically, the function extracts the training and test data from MATLAB file.

# %%
import scipy.io
def load_emnist(file_path='emnist-digits.mat'):
    """
    Loads training and test data with ntr and nts training and test samples
    The `file_path` is the location of the `eminst-balanced.mat`.
    """    
    
    # Load the MATLAB file
    mat = scipy.io.loadmat(file_path)
    
    # Get the training data
    Xtr = mat['dataset'][0][0][0][0][0][0][:]
    ntr = Xtr.shape[0]
    ytr = mat['dataset'][0][0][0][0][0][1][:].reshape(ntr).astype(int)
    
    # Get the test data
    Xts = mat['dataset'][0][0][1][0][0][0][:]
    nts = Xts.shape[0]
    yts = mat['dataset'][0][0][1][0][0][1][:].reshape(nts).astype(int)
    
    print("%d training samples, %d test samples loaded" % (ntr, nts))

    return [Xtr, Xts, ytr, yts]

# %% [markdown]
# Use the function above to get all the digit images from the `emnist-digits.mat` file.

# %%
# TODO:  Load the digit data from emnist-digits.mat
Xtr_dig, Xts_dig, ytr_dig, yts_dig = load_emnist('emnist-digits.mat')
# Out:
# 240000 training samples, 40000 test samples loaded

# %% [markdown]
# You should see 240000 training samples and 40000 test samples.  Now use the same function to get the letter characters from `emnist-letters.mat`.

# %%
# TODO:  Load the digit data from emnist-letters.mat
Xtr_let, Xts_let, ytr_let, yts_let = load_emnist('emnist-letters.mat')
# Out:
# 124800 training samples, 20800 test samples loaded

# %% [markdown]
# You should see 124800 training samples and 20800 test samples.  Next, will recreate the `plt_digit` function from the demo.

# %%
def plt_digit(x,y=None):
    nrow = 28
    ncol = 28
    xsq = x.reshape((nrow,ncol))
    plt.imshow(xsq.T,  cmap='Greys_r')
    plt.xticks([])
    plt.yticks([])    
    if y != None:
        plt.title('%d' % y)

# %% [markdown]
# Plot 8 random samples from the training data.  You can use the `plt_digit` function above with `subplot` to create a nice display.  I suggest sizing your plots using the `plt.figure(figsize=(10,20))` command.

# %%
# TODO:  Plot 8 random samples from the training data of the digits
X = Xtr_dig
y = ytr_dig

# Select random digits
nplt = 8
nsamp = X.shape[0]
Iperm = np.random.permutation(nsamp)

# Plot the images using the subplot command
plt.figure(figsize=(10,20))
for i in range(nplt):
    ind = Iperm[i]
    plt.subplot(1,nplt,i+1)
    plt_digit(X[ind,:], y[ind])

# %% [markdown]
# Next, plot 8 random samples from the letters training data.  You should see that the labels go from 1 to 26, corresponding to `a` to `z`.  Upper and lower case letters belong to the same class.

# %%
# TODO:  Plot 8 random samples from the training data of the letters
X = Xtr_let
y = ytr_let

# Select random digits
nplt = 8
nsamp = X.shape[0]
Iperm = np.random.permutation(nsamp)

# Plot the images using the subplot command
plt.figure(figsize=(10,20))
for i in range(nplt):
    ind = Iperm[i]
    plt.subplot(1,nplt,i+1)
    plt_digit(X[ind,:], y[ind])

# %% [markdown]
# ## Creating a Non-Digit Class
#
# SVM classifiers are very slow to train.  The training is particularly slow when there are a large number of classes.  To speed things up, we are going to put all of the letters in one class and merge that class with the digits data.
#
# Before we begin, we will remove all the samples corresponding to `i/I`, `l/L` and `o/O`, since otherwise these letters would get confused with the digits `0` and `1`.  Create arrays `Xtr_let_rem` and `ytr_let_rem` from the data `Xtr_let` and `ytr_let`, where the samples `i` with `ytr_let[i] == 9, 12, 15` are removed.   Create `Xts_let_rem` and `yts_let_rem` similarly.
#
# If you are clever, you can do this without a for-loop via python broadcasting and `np.all(..., axis=1)` command.  But, if you like, you can use a for-loop.

# %%
remove_list = np.array([9,12,15])

# TODO:  Create arrays with labels 9, 12 and 15 removed
remove_list = [9,12,15]
for i in range(len(remove_list)):
    Xtr_let_rem = Xtr_let[ytr_let != remove_list[i]]
    ytr_let_rem = ytr_let[ytr_let != remove_list[i]]
    Xts_let_rem = Xts_let[yts_let != remove_list[i]]
    yts_let_rem = yts_let[yts_let != remove_list[i]]

#the shapes of the arrays
print(Xtr_let_rem.shape)
print(ytr_let_rem.shape)
print(Xts_let_rem.shape)
print(yts_let_rem.shape)
# Out:
# (120000, 784)
# (120000,)
# (20000, 784)
# (20000,)

# %% [markdown]
# To speed things up even further, we will use only a small subset of the training and test data.  Of course, we will not get great results with this small dataset.  But we can still illustrate the basic concepts.
#
# Create training arrays `Xtr1_dig` and `ytr1_dig` by selecting 5000 random samples from `Xtr_dig` and `ytr_dig`.  Then create training arrays `Xtr1_let` and `ytr1_let` by selecting 1000 random samples from `Xtr_let_rem` and `ytr_let_rem`.  Similarly, create test arrays `Xts1_dig,Xts1_let,yts1_dig,yts1_let` with 5000 digits and 1000 letters.

# %%
import numpy as np

# Number of training and test digits and letters
ntr_dig = 5000
ntr_let = 1000
nts_dig = 5000
nts_let = 1000

# Create training arrays Xtr1_dig and ytr1_dig
idx_tr_dig = np.random.choice(len(Xtr_dig), size=ntr_dig, replace=False)
Xtr1_dig = Xtr_dig[idx_tr_dig,:]
ytr1_dig = ytr_dig[idx_tr_dig]

# Create training arrays Xtr1_let and ytr1_let
idx_tr_let = np.random.choice(len(Xtr_let_rem), size=ntr_let, replace=False)
Xtr1_let = Xtr_let_rem[idx_tr_let,:]
ytr1_let = ytr_let_rem[idx_tr_let]

# Create test arrays Xts1_dig, Xts1_let, yts1_dig, yts1_let
idx_ts_dig = np.random.choice(len(Xts_dig), size=nts_dig, replace=False)
Xts1_dig = Xts_dig[idx_ts_dig,:]
yts1_dig = yts_dig[idx_ts_dig]

idx_ts_let = np.random.choice(len(Xts_let), size=nts_let, replace=False)
Xts1_let = Xts_let[idx_ts_let,:]
yts1_let = yts_let[idx_ts_let]

# %% [markdown]
# Now we will merge our digit and letter training arrays.
# * Create an array `Xtr` by stacking `Xtr1_dig`, `Xtr1_let`.  This should result in 6000 total samples.
# * Create a new label vector `ytr` where `ytr[i] = ytr1_dig[i]` for any digit sample and `ytr[i]=10` for any letter sample.  Thus, all the letters are lumped into the single class with label 10.
#
# Create test arrays `Xts` and `yts` similarly.
#
# You may wish to use the `np.hstack` and `np.vstack` methods.

# %%
# create a vector of ones that is the same length as the letters sample
tens = 10.0*np.ones(len(ytr1_let))

# Create an array `Xtr` by stacking `Xtr1_dig`, `Xtr1_let
Xtr = np.vstack((Xtr1_dig, Xtr1_let))
ytr = np.hstack((ytr1_dig, tens))

print(Xtr.shape)
print(ytr.shape)
Xts, yts = np.vstack((Xts1_dig, Xts1_let)), np.hstack((yts1_dig, tens))
print(Xts.shape)
print(yts.shape)
# Out:
# (6000, 784)
# (6000,)
# (6000, 784)
# (6000,)

# %% [markdown]
# Checking the validity of the transforms

# %%
X = Xtr
y = ytr

# Select random digits
nplt = 8
nsamp = X.shape[0]
Iperm = np.random.permutation(nsamp)

# Plot the images using the subplot command
plt.figure(figsize=(10,20))
for i in range(nplt):
    ind = Iperm[i]
    plt.subplot(1,nplt,i+1)
    plt_digit(X[ind,:], y[ind])

# %% [markdown]
# The features above use pixel values from 0 to 255.  Let's rescale the pixels to the interval from -1.0 to 1.0.  This will yield slightly better performance.  We'll put the scaled data into arrays `Xtr1` and `Xts1`. Note that the pixel data is 8-bit integer, so be careful not to use 8-bit multiplications like `2*Xtr` because they will overflow.

# %%
# Rescale the data to the interval from -1.0 to 1.0
Xtr1 = (Xtr / 127.5) - 1.0 # the .0 is necessary
Xts1 = (Xts / 127.5) - 1.0

# the min and max values of the rescaled data
print(Xtr1.min())
print(Xtr1.max())

# the mind and max of the test data
print(Xts1.min())
print(Xts1.max())
# Out:
# -1.0
# 1.0
# -1.0
# 1.0

# %% [markdown]
# Checking the validity once again

# %%
X = Xtr1
y = ytr

# Select random digits
nplt = 8
nsamp = X.shape[0]
Iperm = np.random.permutation(nsamp)

# Plot the images using the subplot command
plt.figure(figsize=(10,20))
for i in range(nplt):
    ind = Iperm[i]
    plt.subplot(1,nplt,i+1)
    plt_digit(X[ind,:], y[ind])

# %% [markdown]
# ## The SVM classifier
#
# Let's first create an SVM classifer with penalty `C=2.8` and an `rbf` kernel of width `gamma=.0073`. We will reexamine these choices later.

# %%
from sklearn import svm

# Create a classifier: a support vector classifier with RBF kernel
svm = svm.SVC(probability=False, kernel="rbf", C=2.8, gamma=.0073, verbose=1)

# %% [markdown]
# Now we fit the classifier using the scaled training data.  Although SVMs are slow to train, we have kept the training set small, so the fitting should take less than a minute.

# %%
svm.fit(Xtr1,ytr)
# Out:
# [LibSVM]*
# optimization finished, #iter = 367
# obj = -23.854850, rho = -0.592451
# nSV = 195, nBSV = 0
# *
# optimization finished, #iter = 773
# obj = -70.286065, rho = 0.230247
# nSV = 427, nBSV = 0
# *
# optimization finished, #iter = 612
# obj = -54.876902, rho = 0.007415
# nSV = 350, nBSV = 0
# *
# optimization finished, #iter = 631
# obj = -50.593015, rho = 0.047645
# nSV = 361, nBSV = 0
# *
# optimization finished, #iter = 753
# obj = -71.322714, rho = 0.160867
# nSV = 416, nBSV = 0
# *
# optimization finished, #iter = 735
# obj = -67.857883, rho = -0.073742
# nSV = 382, nBSV = 0
# *
# optimization finished, #iter = 516
# obj = -41.233593, rho = -0.149607
# nSV = 295, nBSV = 0
# *
# optimization finished, #iter = 665
# obj = -63.254172, rho = 0.174493
# nSV = 380, nBSV = 0
# *
# optimization finished, #iter = 552
# obj = -46.134477, rho = -0.076823
# nSV = 319, nBSV = 0
# *.*
# optimization finished, #iter = 1261
# obj = -155.392509, rho = 0.803517
# nSV = 668, nBSV = 2
# *
# optimization finished, #iter = 467
# obj = -35.977712, rho = 0.834352
# nSV = 241, nBSV = 0
# *
# optimization finished, #iter = 410
# obj = -30.584695, rho = 0.648988
# nSV = 217, nBSV = 0
# *
# optimization finished, #iter = 509
# obj = -37.275710, rho = 0.720882
# nSV = 243, nBSV = 0
# *
# optimization finished, #iter = 484
# obj = -34.170012, rho = 0.718527
# nSV = 250, nBSV = 0
# *
# optimization finished, #iter = 417
# obj = -32.253890, rho = 0.559597
# nSV = 203, nBSV = 0
# *
# optimization finished, #iter = 492
# obj = -42.499951, rho = 0.526822
# nSV = 201, nBSV = 0
# *
# optimization finished, #iter = 496
# obj = -42.092253, rho = 0.793245
# nSV = 244, nBSV = 0
# *
# optimization finished, #iter = 444
# obj = -34.768104, rho = 0.599270
# nSV = 221, nBSV = 1
# *.*
# optimization finished, #iter = 1306
# obj = -380.537884, rho = 1.166770
# nSV = 459, nBSV = 84
# *
# optimization finished, #iter = 809
# obj = -90.001727, rho = -0.256549
# nSV = 464, nBSV = 0
# *
# optimization finished, #iter = 776
# obj = -70.930669, rho = -0.215104
# nSV = 455, nBSV = 0
# *
# optimization finished, #iter = 875
# obj = -79.866175, rho = -0.128270
# nSV = 498, nBSV = 0
# *
# optimization finished, #iter = 805
# obj = -76.247605, rho = -0.374452
# nSV = 457, nBSV = 0
# *
# optimization finished, #iter = 768
# obj = -68.509174, rho = -0.404947
# nSV = 417, nBSV = 0
# *
# optimization finished, #iter = 931
# obj = -93.545181, rho = -0.065076
# nSV = 527, nBSV = 0
# *
# optimization finished, #iter = 716
# obj = -63.190111, rho = -0.292961
# nSV = 417, nBSV = 0
# .*
# optimization finished, #iter = 1710
# obj = -251.017272, rho = 0.627254
# nSV = 933, nBSV = 5
# *
# optimization finished, #iter = 639
# obj = -48.964300, rho = 0.029690
# nSV = 368, nBSV = 0
# *
# optimization finished, #iter = 843
# obj = -93.386846, rho = 0.113283
# nSV = 464, nBSV = 0
# *
# optimization finished, #iter = 594
# obj = -50.862320, rho = -0.081571
# nSV = 339, nBSV = 0
# *
# optimization finished, #iter = 671
# obj = -66.469325, rho = -0.151241
# nSV = 361, nBSV = 0
# *
# optimization finished, #iter = 830
# obj = -93.014927, rho = 0.197447
# nSV = 465, nBSV = 0
# *
# optimization finished, #iter = 731
# obj = -69.865647, rho = -0.038058
# nSV = 404, nBSV = 0
# *.*
# optimization finished, #iter = 1039
# obj = -137.238379, rho = 0.753933
# nSV = 601, nBSV = 0
# *
# optimization finished, #iter = 811
# obj = -68.425514, rho = 0.069211
# nSV = 466, nBSV = 0
# *
# optimization finished, #iter = 683
# obj = -57.608323, rho = -0.139633
# nSV = 385, nBSV = 0
# *
# optimization finished, #iter = 706
# obj = -68.982924, rho = -0.243381
# nSV = 378, nBSV = 0
# *
# optimization finished, #iter = 823
# obj = -81.093479, rho = 0.158323
# nSV = 464, nBSV = 0
# *
# optimization finished, #iter = 936
# obj = -109.817626, rho = -0.185391
# nSV = 465, nBSV = 1
# .*
# optimization finished, #iter = 1672
# obj = -235.793577, rho = 0.745156
# nSV = 860, nBSV = 5
# *
# optimization finished, #iter = 767
# obj = -75.275149, rho = -0.249485
# nSV = 419, nBSV = 0
# *
# optimization finished, #iter = 670
# obj = -57.832159, rho = -0.274899
# nSV = 383, nBSV = 0
# *
# optimization finished, #iter = 951
# obj = -106.336205, rho = 0.032389
# nSV = 523, nBSV = 0
# *
# optimization finished, #iter = 740
# obj = -69.158276, rho = -0.203324
# nSV = 416, nBSV = 0
# .*
# optimization finished, #iter = 1739
# obj = -232.724577, rho = 0.674220
# nSV = 928, nBSV = 7
# *
# optimization finished, #iter = 482
# obj = -36.874278, rho = -0.067215
# nSV = 284, nBSV = 0
# *
# optimization finished, #iter = 718
# obj = -74.233705, rho = 0.259955
# nSV = 397, nBSV = 0
# *
# optimization finished, #iter = 526
# obj = -42.427304, rho = 0.017052
# nSV = 312, nBSV = 0
# *.*
# optimization finished, #iter = 1289
# obj = -168.126035, rho = 0.870439
# nSV = 691, nBSV = 1
# *
# optimization finished, #iter = 713
# obj = -66.802979, rho = 0.368859
# nSV = 397, nBSV = 0
# *
# optimization finished, #iter = 963
# obj = -124.237368, rho = 0.179102
# nSV = 438, nBSV = 2
# *.*
# optimization finished, #iter = 1064
# obj = -121.862923, rho = 0.836760
# nSV = 578, nBSV = 0
# *
# optimization finished, #iter = 920
# obj = -100.150797, rho = -0.298191
# nSV = 492, nBSV = 0
# .*
# optimization finished, #iter = 1732
# obj = -229.393222, rho = 0.752333
# nSV = 938, nBSV = 0
# .*
# optimization finished, #iter = 1473
# obj = -195.208559, rho = 0.821575
# nSV = 741, nBSV = 9
# Total nSV = 4327
# SVC(C=2.8, gamma=0.0073, verbose=1)

# %% [markdown]
# Now let's compute and print the accuracy on the test data.  This too should take less than a minute.  You should get an accuracy of around 89%.

# %%
# TODO:  Measure error on the test data
yhat_ts = svm.predict(Xts1)
acc = np.mean(yhat_ts == yts)

# %%
print('Accuracy = {0:f}'.format(acc))
# Out:
# Accuracy = 0.903667

# %% [markdown]
# The accuracy is bit lower than what we would get with digits only.  This is because the "letters" class is extremely complex.
#
# To see this, print and then plot the normalized confusion matrix.  You should see that the error rate on the "letters" class is much higher than the others.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# TODO:  Print and plot the normalized confusion matrix
cm = confusion_matrix(yts, yhat_ts)
# plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svm.classes_)
disp.plot()

# %% [markdown]
# Print the following:
# * the fraction of digits that are mislabeled as letters
# * the fraction of letters that are mislabeled as digits

# %%
# the total of each row in the confusion matrix
totalRow = np.sum(cm, axis=1)

# the total of each column in the confusion matrix
totalCol = np.sum(cm, axis=0)

totalDigits = np.sum(totalRow[0:9])
totalLetters = np.sum(totalRow[10:])

# the diagonal elements are the correct predictions
correct = cm.diagonal()

correctDigits = np.sum(correct[0:9])
correctLetters = np.sum(correct[10:])

digitErrorRate = (totalDigits-correctDigits)/totalDigits
letterErrorRate = (totalLetters-correctLetters)/totalLetters

print('Digit error rate = ',digitErrorRate)
print('Letter error rate = ',letterErrorRate)
# Out:
# Digit error rate =  0.0713174850033326
# Letter error rate =  0.23

# %% [markdown]
# ## Optimizing gamma and C via Cross-Validation
#
# Above, and in the demo, we used externally provided `gamma` and `C` values.  In general, these parameters should be carefully chosen.  We will now choose these parameters via cross validation using sklearn's `GridSearchCV` method.
#
# Ideally, we would try many more values for each of the parameters, but this would take a long time.  So, we will try only 3 values for each.  Still, this will take several minutes to complete.

# %% [markdown]
# The `GridSearchCV` method does a train-test split in addition to the parameter search.  In this case, we already have a train-test split, and so we will first combine the train and test data back into a single dataset to use with `GridSearchCV`.
#
# Create arrays `X` and `y` from `Xtr1`, `Xts1`, `ytr` and `yts`.  Use `np.vstack` and `np.hstack`.

# %%
# TODO:  Create combined trained and test data X and y.
X = np.vstack((Xtr1, Xts1))
y = np.hstack((ytr, yts))

# %% [markdown]
# Normally, `GridSearchCV` will do $K$-fold validation and automatically split the data into training and test in each fold.  But, in this case, we want it to use only one fold with a specific train-test split.  To do this, we can do the following:
# * Create a vector `test_fold` where `test_fold[i] = -1` for the samples `i` in the training data (which indicates that they should not be used as test data in any fold) and `test_fold[i] = 0` for the samples `i` in the test data (which indicates that they should be used as test data in fold 0).
# * Run `ps = sklearn.model_selection.PredefinedSplit(test_fold)` to create a predefined test-split object.

# %%
# TODO:  Create a pre-defined test split object 
import sklearn.model_selection

# test_fold is -1 for samples in the training set and 0 for samples in the test set
n_ones = -1*np.ones(len(ytr))
print('The shape of n_ones is {0}'.format(n_ones.shape))
zeros = np.zeros(len(yts))
print('The shape of zeros is {0}'.format(zeros.shape))
test_fold = np.hstack((n_ones, zeros))
# print the shape min and max, and mean of test_fold
print('The mean of test_fold is {0:f}'.format(np.mean(test_fold)))
print('The min of test_fold is {0:f}'.format(np.min(test_fold)))
print('The max of test_fold is {0:f}'.format(np.max(test_fold)))
print('The shape of test_fold is {0}'.format(test_fold.shape))

ps = sklearn.model_selection.PredefinedSplit(test_fold)
# Out:
# The shape of n_ones is (6000,)
# The shape of zeros is (6000,)
# The mean of test_fold is -0.500000
# The min of test_fold is -1.000000
# The max of test_fold is 0.000000
# The shape of test_fold is (12000,)

# %% [markdown]
# Now we are ready to run `GridSearchCV` and call it's `fit` method. Call `GridSearchCV` using `cv=ps` to use our test-split object. Also, use `verbose=10` to have it show progress during fitting.

# %%
from sklearn.model_selection import GridSearchCV
# TODO:  Create a GridSearchCV classifier
C_test = [0.1, 1, 10]
gam_test = [0.001, 0.01, 0.1]
clf = GridSearchCV(svm, param_grid={'C': C_test, 'gamma': gam_test}, cv=ps, verbose=10)

# fit the classifier
clf.fit(X, y)
# Out:
# Fitting 1 folds for each of 9 candidates, totalling 9 fits
# [CV 1/1; 1/9] START C=0.1, gamma=0.001..........................................
# [LibSVM]*
# optimization finished, #iter = 134
# obj = -13.882104, rho = -0.574439
# nSV = 231, nBSV = 215
# *
# optimization finished, #iter = 281
# obj = -32.522191, rho = 0.214959
# nSV = 494, nBSV = 467
# *
# optimization finished, #iter = 245
# obj = -26.258757, rho = -0.114341
# nSV = 417, nBSV = 390
# *
# optimization finished, #iter = 201
# obj = -21.736503, rho = 0.071431
# nSV = 353, nBSV = 331
# *
# optimization finished, #iter = 300
# obj = -35.060038, rho = 0.271560
# nSV = 524, nBSV = 501
# *
# optimization finished, #iter = 283
# obj = -31.930780, rho = -0.084490
# nSV = 490, nBSV = 467
# *
# optimization finished, #iter = 190
# obj = -20.878741, rho = -0.199816
# nSV = 340, nBSV = 323
# *
# optimization finished, #iter = 234
# obj = -25.852049, rho = 0.121102
# nSV = 405, nBSV = 381
# *
# optimization finished, #iter = 190
# obj = -20.870757, rho = -0.106100
# nSV = 333, nBSV = 316
# *
# optimization finished, #iter = 393
# obj = -53.791216, rho = 0.928779
# nSV = 711, nBSV = 691
# *
# optimization finished, #iter = 226
# obj = -25.394354, rho = 1.094330
# nSV = 402, nBSV = 381
# *
# optimization finished, #iter = 181
# obj = -19.112763, rho = 0.629468
# nSV = 314, nBSV = 292
# *
# optimization finished, #iter = 243
# obj = -26.037091, rho = 0.729631
# nSV = 406, nBSV = 383
# *
# optimization finished, #iter = 222
# obj = -25.287663, rho = 1.017110
# nSV = 404, nBSV = 385
# *
# optimization finished, #iter = 186
# obj = -20.352036, rho = 0.564499
# nSV = 328, nBSV = 307
# *
# optimization finished, #iter = 243
# obj = -27.180612, rho = 0.508985
# nSV = 426, nBSV = 410
# *
# optimization finished, #iter = 225
# obj = -28.179605, rho = 0.953869
# nSV = 428, nBSV = 415
# *
# optimization finished, #iter = 219
# obj = -24.040449, rho = 0.581447
# nSV = 387, nBSV = 371
# *
# optimization finished, #iter = 410
# obj = -54.540453, rho = 1.792872
# nSV = 716, nBSV = 687
# *
# optimization finished, #iter = 279
# obj = -33.998993, rho = -0.260007
# nSV = 503, nBSV = 478
# *
# optimization finished, #iter = 246
# obj = -29.022440, rho = -0.256563
# nSV = 444, nBSV = 422
# *
# optimization finished, #iter = 313
# obj = -37.163064, rho = -0.003630
# nSV = 559, nBSV = 532
# *
# optimization finished, #iter = 332
# obj = -40.510239, rho = -0.476833
# nSV = 595, nBSV = 574
# *
# optimization finished, #iter = 319
# obj = -33.103937, rho = -0.389236
# nSV = 521, nBSV = 497
# *
# optimization finished, #iter = 333
# obj = -40.503506, rho = -0.165129
# nSV = 598, nBSV = 578
# *
# optimization finished, #iter = 278
# obj = -28.331856, rho = -0.318697
# nSV = 450, nBSV = 420
# *
# optimization finished, #iter = 521
# obj = -69.759117, rho = 0.880420
# nSV = 889, nBSV = 858
# *
# optimization finished, #iter = 225
# obj = -22.910386, rho = 0.097860
# nSV = 380, nBSV = 354
# *
# optimization finished, #iter = 295
# obj = -37.974709, rho = 0.178518
# nSV = 546, nBSV = 524
# *
# optimization finished, #iter = 242
# obj = -25.165209, rho = -0.047592
# nSV = 409, nBSV = 383
# *
# optimization finished, #iter = 280
# obj = -31.647786, rho = -0.024144
# nSV = 489, nBSV = 466
# *
# optimization finished, #iter = 305
# obj = -36.796006, rho = 0.196304
# nSV = 538, nBSV = 510
# *
# optimization finished, #iter = 304
# obj = -31.979292, rho = 0.056079
# nSV = 501, nBSV = 471
# *
# optimization finished, #iter = 361
# obj = -47.761061, rho = 0.953279
# nSV = 656, nBSV = 631
# *
# optimization finished, #iter = 308
# obj = -36.038035, rho = 0.253916
# nSV = 560, nBSV = 530
# *
# optimization finished, #iter = 228
# obj = -25.802827, rho = -0.107317
# nSV = 411, nBSV = 389
# *
# optimization finished, #iter = 274
# obj = -30.839840, rho = -0.291464
# nSV = 482, nBSV = 457
# *
# optimization finished, #iter = 284
# obj = -35.367374, rho = 0.177079
# nSV = 521, nBSV = 501
# *
# optimization finished, #iter = 360
# obj = -46.088106, rho = -0.202451
# nSV = 661, nBSV = 642
# *
# optimization finished, #iter = 509
# obj = -69.412868, rho = 1.203454
# nSV = 876, nBSV = 847
# *
# optimization finished, #iter = 305
# obj = -36.655026, rho = -0.461565
# nSV = 559, nBSV = 541
# *
# optimization finished, #iter = 269
# obj = -30.598540, rho = -0.487697
# nSV = 481, nBSV = 460
# *
# optimization finished, #iter = 364
# obj = -44.173281, rho = -0.237660
# nSV = 648, nBSV = 623
# *
# optimization finished, #iter = 322
# obj = -34.846281, rho = -0.449110
# nSV = 549, nBSV = 515
# *
# optimization finished, #iter = 565
# obj = -75.702492, rho = 0.989868
# nSV = 951, nBSV = 918
# *
# optimization finished, #iter = 181
# obj = -18.056740, rho = -0.103615
# nSV = 305, nBSV = 284
# *
# optimization finished, #iter = 269
# obj = -32.207844, rho = 0.290709
# nSV = 491, nBSV = 470
# *
# optimization finished, #iter = 199
# obj = -19.880724, rho = -0.010191
# nSV = 328, nBSV = 306
# *
# optimization finished, #iter = 446
# obj = -58.594840, rho = 1.239612
# nSV = 779, nBSV = 750
# *
# optimization finished, #iter = 297
# obj = -33.719880, rho = 0.445785
# nSV = 517, nBSV = 493
# *
# optimization finished, #iter = 380
# obj = -51.025150, rho = 0.331274
# nSV = 714, nBSV = 698
# *
# optimization finished, #iter = 376
# obj = -48.595392, rho = 1.165750
# nSV = 681, nBSV = 665
# *
# optimization finished, #iter = 362
# obj = -43.892076, rho = -0.321030
# nSV = 631, nBSV = 606
# *
# optimization finished, #iter = 507
# obj = -70.148280, rho = 1.026610
# nSV = 880, nBSV = 859
# *
# optimization finished, #iter = 426
# obj = -55.581109, rho = 1.179976
# nSV = 752, nBSV = 732
# Total nSV = 5355
# [CV 1/1; 1/9] END ...........C=0.1, gamma=0.001;, score=0.781 total time=  27.2s
# [CV 1/1; 2/9] START C=0.1, gamma=0.01...........................................
# [LibSVM]*
# optimization finished, #iter = 355
# obj = -17.590146, rho = -0.762742
# nSV = 395, nBSV = 207
# *
# optimization finished, #iter = 489
# obj = -53.053134, rho = 0.464607
# nSV = 834, nBSV = 735
# *
# optimization finished, #iter = 435
# obj = -46.023211, rho = 0.068482
# nSV = 733, nBSV = 654
# *
# optimization finished, #iter = 444
# obj = -44.400575, rho = 0.120839
# nSV = 734, nBSV = 636
# *
# optimization finished, #iter = 485
# obj = -51.742303, rho = 0.322123
# nSV = 815, nBSV = 719
# *
# optimization finished, #iter = 458
# obj = -48.250014, rho = -0.018445
# nSV = 758, nBSV = 670
# *
# optimization finished, #iter = 402
# obj = -37.835419, rho = -0.179558
# nSV = 644, nBSV = 555
# *
# optimization finished, #iter = 452
# obj = -48.175916, rho = 0.235958
# nSV = 766, nBSV = 675
# *
# optimization finished, #iter = 421
# obj = -40.315742, rho = -0.074724
# nSV = 679, nBSV = 578
# *
# optimization finished, #iter = 856
# obj = -64.041086, rho = 0.887926
# nSV = 1109, nBSV = 704
# *
# optimization finished, #iter = 400
# obj = -20.939729, rho = 0.920231
# nSV = 477, nBSV = 249
# *
# optimization finished, #iter = 349
# obj = -19.399932, rho = 0.830089
# nSV = 417, nBSV = 228
# *
# optimization finished, #iter = 377
# obj = -22.413469, rho = 0.879219
# nSV = 467, nBSV = 294
# *
# optimization finished, #iter = 407
# obj = -20.578638, rho = 0.890503
# nSV = 469, nBSV = 243
# *
# optimization finished, #iter = 333
# obj = -19.970205, rho = 0.794640
# nSV = 406, nBSV = 254
# *
# optimization finished, #iter = 308
# obj = -22.987611, rho = 0.771155
# nSV = 422, nBSV = 317
# *
# optimization finished, #iter = 377
# obj = -22.059099, rho = 0.915452
# nSV = 465, nBSV = 283
# *
# optimization finished, #iter = 337
# obj = -21.191107, rho = 0.815130
# nSV = 422, nBSV = 277
# *
# optimization finished, #iter = 474
# obj = -40.035125, rho = 1.060482
# nSV = 616, nBSV = 470
# *
# optimization finished, #iter = 502
# obj = -57.184166, rho = -0.454605
# nSV = 866, nBSV = 773
# *
# optimization finished, #iter = 509
# obj = -55.424986, rho = -0.345418
# nSV = 863, nBSV = 765
# *
# optimization finished, #iter = 519
# obj = -62.303389, rho = -0.174676
# nSV = 942, nBSV = 873
# *
# optimization finished, #iter = 514
# obj = -54.641412, rho = -0.525245
# nSV = 853, nBSV = 748
# *
# optimization finished, #iter = 485
# obj = -49.707573, rho = -0.607819
# nSV = 808, nBSV = 693
# *
# optimization finished, #iter = 521
# obj = -64.535505, rho = -0.291875
# nSV = 941, nBSV = 871
# *
# optimization finished, #iter = 510
# obj = -49.837577, rho = -0.503627
# nSV = 818, nBSV = 690
# *
# optimization finished, #iter = 972
# obj = -85.546758, rho = 0.875981
# nSV = 1239, nBSV = 808
# *
# optimization finished, #iter = 445
# obj = -47.468560, rho = 0.085129
# nSV = 764, nBSV = 683
# *
# optimization finished, #iter = 479
# obj = -57.067259, rho = 0.204973
# nSV = 843, nBSV = 769
# *
# optimization finished, #iter = 427
# obj = -45.390259, rho = -0.104658
# nSV = 739, nBSV = 654
# *
# optimization finished, #iter = 444
# obj = -45.208298, rho = -0.251430
# nSV = 730, nBSV = 640
# *
# optimization finished, #iter = 469
# obj = -57.257899, rho = 0.191744
# nSV = 841, nBSV = 780
# *
# optimization finished, #iter = 449
# obj = -48.886109, rho = -0.131619
# nSV = 767, nBSV = 692
# *
# optimization finished, #iter = 799
# obj = -65.297079, rho = 0.873016
# nSV = 1099, nBSV = 715
# *
# optimization finished, #iter = 496
# obj = -56.385088, rho = 0.212500
# nSV = 876, nBSV = 793
# *
# optimization finished, #iter = 440
# obj = -46.400187, rho = -0.168329
# nSV = 747, nBSV = 660
# *
# optimization finished, #iter = 461
# obj = -47.290180, rho = -0.407852
# nSV = 767, nBSV = 665
# *
# optimization finished, #iter = 485
# obj = -56.547918, rho = 0.116595
# nSV = 849, nBSV = 773
# *
# optimization finished, #iter = 496
# obj = -59.837550, rho = -0.282150
# nSV = 876, nBSV = 815
# *
# optimization finished, #iter = 895
# obj = -75.286665, rho = 0.929583
# nSV = 1183, nBSV = 766
# *
# optimization finished, #iter = 496
# obj = -52.537899, rho = -0.362944
# nSV = 825, nBSV = 725
# *
# optimization finished, #iter = 490
# obj = -45.339350, rho = -0.477962
# nSV = 756, nBSV = 629
# *
# optimization finished, #iter = 508
# obj = -63.545622, rho = -0.116292
# nSV = 917, nBSV = 856
# *
# optimization finished, #iter = 495
# obj = -50.984952, rho = -0.392200
# nSV = 816, nBSV = 710
# *.*
# optimization finished, #iter = 1013
# obj = -81.483432, rho = 0.909455
# nSV = 1280, nBSV = 782
# *
# optimization finished, #iter = 392
# obj = -36.997263, rho = -0.151513
# nSV = 639, nBSV = 545
# *
# optimization finished, #iter = 477
# obj = -51.484735, rho = 0.295990
# nSV = 805, nBSV = 706
# *
# optimization finished, #iter = 427
# obj = -40.038347, rho = -0.039462
# nSV = 685, nBSV = 579
# *
# optimization finished, #iter = 817
# obj = -65.468598, rho = 0.925287
# nSV = 1115, nBSV = 713
# *
# optimization finished, #iter = 467
# obj = -48.121986, rho = 0.476982
# nSV = 776, nBSV = 672
# *
# optimization finished, #iter = 482
# obj = -56.274772, rho = 0.204898
# nSV = 833, nBSV = 758
# *
# optimization finished, #iter = 853
# obj = -56.467947, rho = 0.916040
# nSV = 1052, nBSV = 650
# *
# optimization finished, #iter = 503
# obj = -57.170247, rho = -0.399180
# nSV = 864, nBSV = 775
# *
# optimization finished, #iter = 935
# obj = -78.659154, rho = 0.906078
# nSV = 1223, nBSV = 790
# *
# optimization finished, #iter = 915
# obj = -64.646695, rho = 0.912904
# nSV = 1144, nBSV = 709
# Total nSV = 5553
# [CV 1/1; 2/9] END ............C=0.1, gamma=0.01;, score=0.599 total time=  33.2s
# [CV 1/1; 3/9] START C=0.1, gamma=0.1............................................
# [LibSVM]*
# optimization finished, #iter = 511
# obj = -93.031573, rho = -0.314063
# nSV = 1022, nBSV = 1022
# *.*
# optimization finished, #iter = 1019
# obj = -97.106106, rho = 0.900779
# nSV = 1026, nBSV = 514
# *.*
# optimization finished, #iter = 1396
# obj = -90.413992, rho = -0.906912
# nSV = 986, nBSV = 475
# *.*
# optimization finished, #iter = 1148
# obj = -91.527101, rho = -0.905737
# nSV = 992, nBSV = 481
# *
# optimization finished, #iter = 889
# obj = -96.531065, rho = -0.900593
# nSV = 1019, nBSV = 635
# *.*
# optimization finished, #iter = 1261
# obj = -92.453276, rho = -0.904757
# nSV = 997, nBSV = 486
# *.*
# optimization finished, #iter = 1008
# obj = -95.770590, rho = -0.901229
# nSV = 1015, nBSV = 504
# *.*
# optimization finished, #iter = 1193
# obj = -95.050017, rho = -0.902013
# nSV = 1011, nBSV = 500
# *
# optimization finished, #iter = 762
# obj = -96.712304, rho = -0.900504
# nSV = 1020, nBSV = 765
# .*
# optimization finished, #iter = 1901
# obj = -98.325765, rho = 0.948512
# nSV = 1511, nBSV = 511
# *.*
# optimization finished, #iter = 1019
# obj = -93.055025, rho = 0.900779
# nSV = 1026, nBSV = 514
# *
# optimization finished, #iter = 535
# obj = -87.686263, rho = -0.653348
# nSV = 975, nBSV = 915
# *
# optimization finished, #iter = 530
# obj = -88.640300, rho = -0.628089
# nSV = 981, nBSV = 935
# *
# optimization finished, #iter = 515
# obj = -92.650972, rho = -0.369200
# nSV = 1019, nBSV = 1012
# *
# optimization finished, #iter = 530
# obj = -89.421586, rho = -0.602241
# nSV = 988, nBSV = 948
# *
# optimization finished, #iter = 513
# obj = -92.086438, rho = -0.455761
# nSV = 1011, nBSV = 1001
# *
# optimization finished, #iter = 521
# obj = -91.533368, rho = -0.503000
# nSV = 1006, nBSV = 989
# *
# optimization finished, #iter = 519
# obj = -92.778043, rho = -0.345899
# nSV = 1020, nBSV = 1014
# .*
# optimization finished, #iter = 1893
# obj = -94.979569, rho = 0.951217
# nSV = 1511, nBSV = 550
# *.*
# optimization finished, #iter = 1340
# obj = -90.434229, rho = -0.907765
# nSV = 990, nBSV = 475
# *.*
# optimization finished, #iter = 1165
# obj = -91.547852, rho = -0.906600
# nSV = 996, nBSV = 481
# *.*
# optimization finished, #iter = 1016
# obj = -96.554204, rho = -0.901357
# nSV = 1023, nBSV = 508
# *.*
# optimization finished, #iter = 1278
# obj = -92.474465, rho = -0.905629
# nSV = 1001, nBSV = 486
# *.*
# optimization finished, #iter = 1197
# obj = -95.793374, rho = -0.902133
# nSV = 1019, nBSV = 504
# *.*
# optimization finished, #iter = 1070
# obj = -95.072440, rho = -0.902910
# nSV = 1015, nBSV = 500
# *.*
# optimization finished, #iter = 1018
# obj = -96.735526, rho = -0.901163
# nSV = 1024, nBSV = 509
# .*.*
# optimization finished, #iter = 2074
# obj = -99.088637, rho = 0.948106
# nSV = 1515, nBSV = 515
# *
# optimization finished, #iter = 950
# obj = -90.278615, rho = 0.901214
# nSV = 956, nBSV = 475
# *.*
# optimization finished, #iter = 1090
# obj = -90.403880, rho = 0.906488
# nSV = 983, nBSV = 475
# *.*
# optimization finished, #iter = 1168
# obj = -90.301402, rho = 0.902172
# nSV = 961, nBSV = 475
# *.*
# optimization finished, #iter = 1205
# obj = -90.369404, rho = 0.905035
# nSV = 979, nBSV = 475
# *.*
# optimization finished, #iter = 1250
# obj = -90.368287, rho = 0.904989
# nSV = 975, nBSV = 475
# *.*
# optimization finished, #iter = 1195
# obj = -90.404974, rho = 0.906534
# nSV = 984, nBSV = 475
# .*.*
# optimization finished, #iter = 2249
# obj = -91.488073, rho = 0.952137
# nSV = 1475, nBSV = 475
# *.*
# optimization finished, #iter = 1318
# obj = -91.516770, rho = 0.905307
# nSV = 989, nBSV = 481
# *
# optimization finished, #iter = 962
# obj = -91.411666, rho = 0.900937
# nSV = 967, nBSV = 481
# *.*
# optimization finished, #iter = 1234
# obj = -91.481407, rho = 0.903835
# nSV = 985, nBSV = 481
# *.*
# optimization finished, #iter = 1286
# obj = -91.480283, rho = 0.903789
# nSV = 981, nBSV = 481
# *.*
# optimization finished, #iter = 1328
# obj = -91.517951, rho = 0.905354
# nSV = 990, nBSV = 481
# .*
# optimization finished, #iter = 1985
# obj = -92.628543, rho = 0.951535
# nSV = 1481, nBSV = 481
# *.*
# optimization finished, #iter = 1284
# obj = -92.442706, rho = -0.904322
# nSV = 994, nBSV = 486
# *.*
# optimization finished, #iter = 1008
# obj = -95.759260, rho = -0.900779
# nSV = 1012, nBSV = 504
# *.*
# optimization finished, #iter = 1004
# obj = -95.038867, rho = -0.901566
# nSV = 1008, nBSV = 500
# *
# optimization finished, #iter = 584
# obj = -96.520786, rho = 0.900500
# nSV = 1017, nBSV = 940
# .*
# optimization finished, #iter = 1901
# obj = -97.759557, rho = 0.948813
# nSV = 1508, nBSV = 508
# *.*
# optimization finished, #iter = 1078
# obj = -92.406603, rho = 0.902838
# nSV = 990, nBSV = 486
# *.*
# optimization finished, #iter = 1076
# obj = -92.405452, rho = 0.902789
# nSV = 986, nBSV = 486
# *.*
# optimization finished, #iter = 1254
# obj = -92.443865, rho = 0.904369
# nSV = 995, nBSV = 486
# .*
# optimization finished, #iter = 1944
# obj = -93.577701, rho = 0.951029
# nSV = 1486, nBSV = 486
# *
# optimization finished, #iter = 624
# obj = -95.000628, rho = -0.900406
# nSV = 1004, nBSV = 876
# *.*
# optimization finished, #iter = 1008
# obj = -95.760543, rho = 0.900829
# nSV = 1013, nBSV = 504
# .*
# optimization finished, #iter = 1896
# obj = -96.979885, rho = 0.949216
# nSV = 1504, nBSV = 504
# *.*
# optimization finished, #iter = 1067
# obj = -95.040058, rho = 0.901615
# nSV = 1009, nBSV = 500
# .*
# optimization finished, #iter = 1453
# obj = -96.240121, rho = 0.949617
# nSV = 1500, nBSV = 500
# .*
# optimization finished, #iter = 1899
# obj = -97.945777, rho = 0.948715
# nSV = 1509, nBSV = 509
# Total nSV = 6000
# [CV 1/1; 3/9] END .............C=0.1, gamma=0.1;, score=0.167 total time=  40.7s
# [CV 1/1; 4/9] START C=1, gamma=0.001............................................
# [LibSVM]*
# optimization finished, #iter = 96
# obj = -38.233135, rho = -0.651671
# nSV = 74, nBSV = 47
# *
# optimization finished, #iter = 264
# obj = -96.954618, rho = 0.379369
# nSV = 188, nBSV = 123
# *
# optimization finished, #iter = 273
# obj = -66.326457, rho = -0.119873
# nSV = 140, nBSV = 75
# *
# optimization finished, #iter = 199
# obj = -59.687318, rho = 0.113256
# nSV = 125, nBSV = 73
# *
# optimization finished, #iter = 352
# obj = -105.528761, rho = 0.393055
# nSV = 216, nBSV = 133
# *
# optimization finished, #iter = 219
# obj = -85.391549, rho = -0.437694
# nSV = 163, nBSV = 113
# *
# optimization finished, #iter = 182
# obj = -47.837584, rho = -0.284848
# nSV = 114, nBSV = 59
# *
# optimization finished, #iter = 243
# obj = -77.099008, rho = 0.354658
# nSV = 150, nBSV = 90
# *
# optimization finished, #iter = 213
# obj = -53.501939, rho = -0.101647
# nSV = 120, nBSV = 62
# *
# optimization finished, #iter = 491
# obj = -253.670316, rho = 2.254690
# nSV = 386, nBSV = 300
# *
# optimization finished, #iter = 192
# obj = -73.443321, rho = 1.424276
# nSV = 136, nBSV = 92
# *
# optimization finished, #iter = 148
# obj = -52.983642, rho = 0.732850
# nSV = 103, nBSV = 63
# *
# optimization finished, #iter = 189
# obj = -71.787207, rho = 1.035084
# nSV = 137, nBSV = 94
# *
# optimization finished, #iter = 208
# obj = -70.124388, rho = 1.088336
# nSV = 134, nBSV = 87
# *
# optimization finished, #iter = 140
# obj = -57.652430, rho = 0.363927
# nSV = 111, nBSV = 77
# *
# optimization finished, #iter = 224
# obj = -74.551006, rho = 0.492993
# nSV = 144, nBSV = 97
# *
# optimization finished, #iter = 175
# obj = -92.389071, rho = 1.232126
# nSV = 162, nBSV = 123
# *
# optimization finished, #iter = 190
# obj = -60.285629, rho = 0.470198
# nSV = 120, nBSV = 74
# *
# optimization finished, #iter = 495
# obj = -311.632441, rho = 2.968821
# nSV = 408, nBSV = 344
# *
# optimization finished, #iter = 235
# obj = -120.571434, rho = -0.416177
# nSV = 204, nBSV = 150
# *
# optimization finished, #iter = 292
# obj = -92.941914, rho = -0.295806
# nSV = 179, nBSV = 108
# *
# optimization finished, #iter = 270
# obj = -116.591944, rho = -0.081846
# nSV = 219, nBSV = 150
# *
# optimization finished, #iter = 310
# obj = -130.032533, rho = -1.109595
# nSV = 243, nBSV = 173
# *
# optimization finished, #iter = 322
# obj = -86.452749, rho = -0.772071
# nSV = 179, nBSV = 105
# *
# optimization finished, #iter = 308
# obj = -125.995400, rho = -0.347108
# nSV = 237, nBSV = 166
# *
# optimization finished, #iter = 253
# obj = -77.767138, rho = -0.346710
# nSV = 160, nBSV = 89
# *
# optimization finished, #iter = 559
# obj = -387.792287, rho = 1.973284
# nSV = 543, nBSV = 456
# *
# optimization finished, #iter = 178
# obj = -53.875773, rho = 0.053091
# nSV = 123, nBSV = 71
# *
# optimization finished, #iter = 368
# obj = -134.068580, rho = 0.588834
# nSV = 237, nBSV = 155
# *
# optimization finished, #iter = 207
# obj = -59.669349, rho = -0.029131
# nSV = 130, nBSV = 75
# *
# optimization finished, #iter = 278
# obj = -91.246052, rho = -0.208902
# nSV = 179, nBSV = 112
# *
# optimization finished, #iter = 296
# obj = -124.740046, rho = 0.513755
# nSV = 224, nBSV = 158
# *
# optimization finished, #iter = 279
# obj = -95.899796, rho = 0.141635
# nSV = 184, nBSV = 115
# *
# optimization finished, #iter = 379
# obj = -217.749918, rho = 2.040894
# nSV = 336, nBSV = 257
# *
# optimization finished, #iter = 312
# obj = -103.138591, rho = 0.060516
# nSV = 207, nBSV = 127
# *
# optimization finished, #iter = 234
# obj = -70.381683, rho = -0.419386
# nSV = 141, nBSV = 84
# *
# optimization finished, #iter = 253
# obj = -87.508248, rho = -0.242223
# nSV = 170, nBSV = 108
# *
# optimization finished, #iter = 308
# obj = -114.620204, rho = 0.316320
# nSV = 212, nBSV = 144
# *
# optimization finished, #iter = 333
# obj = -156.949161, rho = -0.433122
# nSV = 268, nBSV = 208
# *
# optimization finished, #iter = 541
# obj = -377.553082, rho = 1.976860
# nSV = 537, nBSV = 445
# *
# optimization finished, #iter = 318
# obj = -106.095046, rho = -0.650426
# nSV = 207, nBSV = 132
# *
# optimization finished, #iter = 218
# obj = -80.674958, rho = -0.460290
# nSV = 163, nBSV = 106
# *
# optimization finished, #iter = 365
# obj = -157.406774, rho = -0.492653
# nSV = 276, nBSV = 193
# *
# optimization finished, #iter = 263
# obj = -98.307225, rho = -0.349049
# nSV = 189, nBSV = 127
# *
# optimization finished, #iter = 701
# obj = -395.011870, rho = 1.629130
# nSV = 587, nBSV = 467
# *
# optimization finished, #iter = 162
# obj = -37.922242, rho = -0.101290
# nSV = 94, nBSV = 42
# *
# optimization finished, #iter = 233
# obj = -98.003314, rho = 0.438098
# nSV = 182, nBSV = 123
# *
# optimization finished, #iter = 158
# obj = -45.601323, rho = 0.075907
# nSV = 104, nBSV = 58
# *
# optimization finished, #iter = 461
# obj = -277.138598, rho = 2.648260
# nSV = 416, nBSV = 332
# *
# optimization finished, #iter = 276
# obj = -93.041515, rho = 0.745875
# nSV = 189, nBSV = 125
# *
# optimization finished, #iter = 366
# obj = -195.167214, rho = 0.582393
# nSV = 312, nBSV = 252
# *
# optimization finished, #iter = 375
# obj = -195.615514, rho = 2.010984
# nSV = 316, nBSV = 240
# *
# optimization finished, #iter = 347
# obj = -153.945339, rho = -0.602794
# nSV = 268, nBSV = 195
# *
# optimization finished, #iter = 570
# obj = -390.600074, rho = 2.509669
# nSV = 543, nBSV = 453
# *
# optimization finished, #iter = 481
# obj = -260.509138, rho = 2.292505
# nSV = 390, nBSV = 304
# Total nSV = 3618
# [CV 1/1; 4/9] END .............C=1, gamma=0.001;, score=0.860 total time=  15.9s
# [CV 1/1; 5/9] START C=1, gamma=0.01.............................................
# [LibSVM]*
# optimization finished, #iter = 488
# obj = -29.862131, rho = -0.634486
# nSV = 294, nBSV = 8
# *
# optimization finished, #iter = 972
# obj = -97.609646, rho = 0.275732
# nSV = 592, nBSV = 7
# *
# optimization finished, #iter = 805
# obj = -79.325609, rho = 0.051047
# nSV = 491, nBSV = 2
# *
# optimization finished, #iter = 832
# obj = -74.052406, rho = 0.063227
# nSV = 510, nBSV = 6
# *
# optimization finished, #iter = 937
# obj = -95.377220, rho = 0.169120
# nSV = 564, nBSV = 11
# *
# optimization finished, #iter = 898
# obj = -89.503904, rho = -0.035892
# nSV = 527, nBSV = 10
# *
# optimization finished, #iter = 720
# obj = -60.672335, rho = -0.144079
# nSV = 423, nBSV = 3
# *
# optimization finished, #iter = 886
# obj = -87.969498, rho = 0.195561
# nSV = 551, nBSV = 9
# *
# optimization finished, #iter = 735
# obj = -67.156057, rho = -0.054366
# nSV = 452, nBSV = 5
# .*
# optimization finished, #iter = 1487
# obj = -163.921883, rho = 0.748362
# nSV = 950, nBSV = 69
# *
# optimization finished, #iter = 601
# obj = -39.183468, rho = 0.843761
# nSV = 366, nBSV = 13
# *
# optimization finished, #iter = 511
# obj = -35.069485, rho = 0.712444
# nSV = 317, nBSV = 10
# *
# optimization finished, #iter = 644
# obj = -41.582385, rho = 0.765196
# nSV = 355, nBSV = 12
# *
# optimization finished, #iter = 633
# obj = -37.930371, rho = 0.767951
# nSV = 377, nBSV = 13
# *
# optimization finished, #iter = 546
# obj = -36.810887, rho = 0.643027
# nSV = 303, nBSV = 13
# *
# optimization finished, #iter = 551
# obj = -44.651652, rho = 0.620115
# nSV = 286, nBSV = 18
# *
# optimization finished, #iter = 585
# obj = -43.615375, rho = 0.824495
# nSV = 340, nBSV = 16
# *
# optimization finished, #iter = 552
# obj = -38.678697, rho = 0.663904
# nSV = 311, nBSV = 11
# *.*
# optimization finished, #iter = 1013
# obj = -184.668205, rho = 1.070847
# nSV = 500, nBSV = 133
# *
# optimization finished, #iter = 983
# obj = -118.013916, rho = -0.241421
# nSV = 638, nBSV = 25
# *
# optimization finished, #iter = 978
# obj = -100.567135, rho = -0.222008
# nSV = 629, nBSV = 10
# *.*
# optimization finished, #iter = 1077
# obj = -113.611969, rho = -0.135137
# nSV = 673, nBSV = 4
# *.*
# optimization finished, #iter = 1005
# obj = -101.889894, rho = -0.351322
# nSV = 611, nBSV = 14
# *.*
# optimization finished, #iter = 1009
# obj = -92.342917, rho = -0.425910
# nSV = 584, nBSV = 19
# *.*
# optimization finished, #iter = 1121
# obj = -130.091099, rho = -0.082382
# nSV = 693, nBSV = 12
# *
# optimization finished, #iter = 923
# obj = -90.440761, rho = -0.320955
# nSV = 580, nBSV = 11
# .*
# optimization finished, #iter = 1797
# obj = -265.186446, rho = 0.555326
# nSV = 1153, nBSV = 115
# *
# optimization finished, #iter = 849
# obj = -77.180797, rho = 0.010054
# nSV = 537, nBSV = 3
# *.*
# optimization finished, #iter = 1009
# obj = -119.619901, rho = 0.096954
# nSV = 615, nBSV = 22
# *
# optimization finished, #iter = 807
# obj = -75.891398, rho = -0.096516
# nSV = 493, nBSV = 2
# *
# optimization finished, #iter = 823
# obj = -83.914850, rho = -0.192295
# nSV = 502, nBSV = 10
# *.*
# optimization finished, #iter = 983
# obj = -120.863440, rho = 0.168745
# nSV = 616, nBSV = 23
# *
# optimization finished, #iter = 885
# obj = -91.380729, rho = -0.089767
# nSV = 538, nBSV = 19
# .*
# optimization finished, #iter = 1412
# obj = -163.650391, rho = 0.685384
# nSV = 928, nBSV = 49
# *.*
# optimization finished, #iter = 1025
# obj = -97.285726, rho = 0.082061
# nSV = 637, nBSV = 6
# *
# optimization finished, #iter = 852
# obj = -80.569535, rho = -0.115830
# nSV = 530, nBSV = 11
# *
# optimization finished, #iter = 853
# obj = -89.628203, rho = -0.245853
# nSV = 506, nBSV = 16
# *.*
# optimization finished, #iter = 1004
# obj = -109.189469, rho = 0.146431
# nSV = 621, nBSV = 12
# *.*
# optimization finished, #iter = 1060
# obj = -129.239968, rho = -0.162255
# nSV = 628, nBSV = 32
# .*
# optimization finished, #iter = 1671
# obj = -233.029317, rho = 0.735607
# nSV = 1099, nBSV = 118
# *
# optimization finished, #iter = 926
# obj = -98.741400, rho = -0.217267
# nSV = 570, nBSV = 13
# *
# optimization finished, #iter = 884
# obj = -79.205154, rho = -0.301058
# nSV = 541, nBSV = 9
# *.*
# optimization finished, #iter = 1071
# obj = -134.601546, rho = 0.038667
# nSV = 670, nBSV = 22
# *
# optimization finished, #iter = 946
# obj = -93.507524, rho = -0.217622
# nSV = 580, nBSV = 14
# .*
# optimization finished, #iter = 1806
# obj = -237.174186, rho = 0.663328
# nSV = 1152, nBSV = 105
# *
# optimization finished, #iter = 699
# obj = -57.403875, rho = -0.095467
# nSV = 423, nBSV = 1
# *
# optimization finished, #iter = 877
# obj = -99.041988, rho = 0.251911
# nSV = 542, nBSV = 13
# *
# optimization finished, #iter = 735
# obj = -64.512733, rho = -0.004095
# nSV = 449, nBSV = 1
# .*
# optimization finished, #iter = 1459
# obj = -175.749789, rho = 0.789411
# nSV = 968, nBSV = 79
# *
# optimization finished, #iter = 897
# obj = -88.763446, rho = 0.366719
# nSV = 546, nBSV = 10
# *
# optimization finished, #iter = 972
# obj = -130.443566, rho = 0.186666
# nSV = 561, nBSV = 51
# *.*
# optimization finished, #iter = 1395
# obj = -133.782642, rho = 0.804257
# nSV = 874, nBSV = 61
# *.*
# optimization finished, #iter = 1035
# obj = -121.244847, rho = -0.293465
# nSV = 622, nBSV = 22
# .*
# optimization finished, #iter = 1805
# obj = -242.114074, rho = 0.670478
# nSV = 1157, nBSV = 107
# .*
# optimization finished, #iter = 1597
# obj = -180.781737, rho = 0.772515
# nSV = 992, nBSV = 82
# Total nSV = 4600
# [CV 1/1; 5/9] END ..............C=1, gamma=0.01;, score=0.887 total time=  28.8s
# [CV 1/1; 6/9] START C=1, gamma=0.1..............................................
# [LibSVM].*.*
# optimization finished, #iter = 2001
# obj = -356.048311, rho = -0.332121
# nSV = 995, nBSV = 156
# .*
# optimization finished, #iter = 1489
# obj = -512.611261, rho = 0.007984
# nSV = 1026, nBSV = 486
# .*
# optimization finished, #iter = 1912
# obj = -491.399410, rho = -0.069123
# nSV = 986, nBSV = 475
# .*
# optimization finished, #iter = 1866
# obj = -494.713325, rho = -0.057365
# nSV = 992, nBSV = 481
# .*
# optimization finished, #iter = 1747
# obj = -509.108128, rho = -0.004453
# nSV = 1019, nBSV = 507
# .*.*
# optimization finished, #iter = 2084
# obj = -497.329971, rho = -0.047566
# nSV = 997, nBSV = 486
# .*
# optimization finished, #iter = 1821
# obj = -505.150477, rho = -0.016257
# nSV = 1015, nBSV = 451
# .*.*
# optimization finished, #iter = 2046
# obj = -505.004116, rho = -0.020130
# nSV = 1011, nBSV = 500
# *.*
# optimization finished, #iter = 1483
# obj = -509.235018, rho = -0.003221
# nSV = 1020, nBSV = 434
# ..*
# optimization finished, #iter = 2835
# obj = -634.577855, rho = 0.485106
# nSV = 1511, nBSV = 511
# .*
# optimization finished, #iter = 1955
# obj = -357.092521, rho = 0.336882
# nSV = 999, nBSV = 157
# .*
# optimization finished, #iter = 1848
# obj = -347.728650, rho = 0.294407
# nSV = 959, nBSV = 148
# .*
# optimization finished, #iter = 1856
# obj = -349.177002, rho = 0.300962
# nSV = 965, nBSV = 149
# .*
# optimization finished, #iter = 1999
# obj = -355.529810, rho = 0.329747
# nSV = 992, nBSV = 156
# .*
# optimization finished, #iter = 1842
# obj = -350.319135, rho = 0.306127
# nSV = 970, nBSV = 149
# .*
# optimization finished, #iter = 1914
# obj = -353.790420, rho = 0.321774
# nSV = 988, nBSV = 153
# .*
# optimization finished, #iter = 1906
# obj = -353.708154, rho = 0.321508
# nSV = 984, nBSV = 153
# .*
# optimization finished, #iter = 1998
# obj = -355.591629, rho = 0.330026
# nSV = 993, nBSV = 156
# .*.*
# optimization finished, #iter = 2575
# obj = -448.581246, rho = 0.629408
# nSV = 1486, nBSV = 274
# .*.*
# optimization finished, #iter = 1984
# obj = -493.423664, rho = -0.077646
# nSV = 990, nBSV = 475
# .*.*
# optimization finished, #iter = 1993
# obj = -496.789048, rho = -0.065996
# nSV = 996, nBSV = 481
# .*
# optimization finished, #iter = 1896
# obj = -511.423444, rho = -0.013567
# nSV = 1023, nBSV = 508
# .*.*
# optimization finished, #iter = 2133
# obj = -499.449041, rho = -0.056287
# nSV = 1001, nBSV = 486
# .*
# optimization finished, #iter = 1862
# obj = -507.413134, rho = -0.024563
# nSV = 1019, nBSV = 465
# .*
# optimization finished, #iter = 1937
# obj = -507.247060, rho = -0.029101
# nSV = 1015, nBSV = 500
# .*
# optimization finished, #iter = 1744
# obj = -511.557618, rho = -0.011847
# nSV = 1024, nBSV = 497
# ..*.*
# optimization finished, #iter = 3314
# obj = -638.869809, rho = 0.481073
# nSV = 1515, nBSV = 515
# .*
# optimization finished, #iter = 1871
# obj = -477.864776, rho = 0.012135
# nSV = 956, nBSV = 475
# .*.*
# optimization finished, #iter = 1997
# obj = -490.391130, rho = 0.064878
# nSV = 983, nBSV = 475
# .*.*
# optimization finished, #iter = 1972
# obj = -480.141439, rho = 0.021721
# nSV = 961, nBSV = 475
# .*
# optimization finished, #iter = 1840
# obj = -486.941160, rho = 0.050352
# nSV = 979, nBSV = 475
# .*.*
# optimization finished, #iter = 2168
# obj = -486.832219, rho = 0.049893
# nSV = 975, nBSV = 475
# .*.*
# optimization finished, #iter = 2014
# obj = -490.500355, rho = 0.065338
# nSV = 984, nBSV = 475
# ..*.*
# optimization finished, #iter = 3150
# obj = -598.809746, rho = 0.521377
# nSV = 1475, nBSV = 475
# .*.*
# optimization finished, #iter = 2165
# obj = -493.679376, rho = 0.053066
# nSV = 989, nBSV = 481
# .*
# optimization finished, #iter = 1863
# obj = -483.169126, rho = 0.009376
# nSV = 967, nBSV = 478
# .*.*
# optimization finished, #iter = 1989
# obj = -490.142041, rho = 0.038357
# nSV = 985, nBSV = 481
# .*.*
# optimization finished, #iter = 2149
# obj = -490.030024, rho = 0.037891
# nSV = 981, nBSV = 481
# .*
# optimization finished, #iter = 1828
# obj = -493.795280, rho = 0.053539
# nSV = 990, nBSV = 481
# ..*
# optimization finished, #iter = 2878
# obj = -604.856817, rho = 0.515337
# nSV = 1481, nBSV = 481
# .*.*
# optimization finished, #iter = 2066
# obj = -496.274394, rho = -0.043222
# nSV = 994, nBSV = 486
# .*
# optimization finished, #iter = 1682
# obj = -504.024934, rho = -0.012243
# nSV = 1012, nBSV = 437
# .*
# optimization finished, #iter = 1507
# obj = -503.886884, rho = -0.015661
# nSV = 1008, nBSV = 500
# *.*
# optimization finished, #iter = 1007
# obj = -508.079819, rho = 0.000295
# nSV = 1017, nBSV = 208
# ..*
# optimization finished, #iter = 2795
# obj = -631.961355, rho = 0.488125
# nSV = 1508, nBSV = 508
# .*
# optimization finished, #iter = 1891
# obj = -492.662772, rho = 0.028360
# nSV = 990, nBSV = 486
# .*
# optimization finished, #iter = 1937
# obj = -492.548750, rho = 0.027890
# nSV = 986, nBSV = 486
# .*.*
# optimization finished, #iter = 2073
# obj = -496.388764, rho = 0.043693
# nSV = 995, nBSV = 486
# ..*
# optimization finished, #iter = 2832
# obj = -609.773141, rho = 0.510295
# nSV = 1486, nBSV = 486
# *.*
# optimization finished, #iter = 1074
# obj = -500.064219, rho = -0.000298
# nSV = 1004, nBSV = 241
# .*
# optimization finished, #iter = 1741
# obj = -504.154020, rho = 0.012688
# nSV = 1013, nBSV = 438
# ..*
# optimization finished, #iter = 2900
# obj = -625.989299, rho = 0.492160
# nSV = 1504, nBSV = 504
# .*
# optimization finished, #iter = 1911
# obj = -504.008059, rho = 0.016145
# nSV = 1009, nBSV = 500
# .*.*
# optimization finished, #iter = 2554
# obj = -624.018353, rho = 0.496187
# nSV = 1500, nBSV = 500
# ..*.*
# optimization finished, #iter = 3170
# obj = -632.582650, rho = 0.487144
# nSV = 1509, nBSV = 509
# Total nSV = 5977
# [CV 1/1; 6/9] END ...............C=1, gamma=0.1;, score=0.210 total time=  41.0s
# [CV 1/1; 7/9] START C=10, gamma=0.001...........................................
# [LibSVM]*
# optimization finished, #iter = 170
# obj = -67.496721, rho = -0.275971
# nSV = 50, nBSV = 2
# *
# optimization finished, #iter = 605
# obj = -160.514981, rho = 0.631944
# nSV = 125, nBSV = 2
# *
# optimization finished, #iter = 425
# obj = -100.843229, rho = 0.043117
# nSV = 102, nBSV = 1
# *
# optimization finished, #iter = 419
# obj = -111.896863, rho = 0.403224
# nSV = 90, nBSV = 2
# *
# optimization finished, #iter = 588
# obj = -198.764450, rho = 1.045903
# nSV = 129, nBSV = 7
# *
# optimization finished, #iter = 409
# obj = -153.510979, rho = -0.449745
# nSV = 103, nBSV = 6
# *
# optimization finished, #iter = 269
# obj = -69.365343, rho = -0.178916
# nSV = 74, nBSV = 0
# *
# optimization finished, #iter = 487
# obj = -150.672219, rho = 0.696028
# nSV = 110, nBSV = 3
# *
# optimization finished, #iter = 324
# obj = -90.229957, rho = -0.267702
# nSV = 87, nBSV = 1
# .*
# optimization finished, #iter = 1610
# obj = -894.419517, rho = 4.917888
# nSV = 284, nBSV = 65
# *
# optimization finished, #iter = 415
# obj = -153.689846, rho = 1.348446
# nSV = 91, nBSV = 4
# *
# optimization finished, #iter = 371
# obj = -106.990840, rho = 0.430662
# nSV = 78, nBSV = 3
# *
# optimization finished, #iter = 466
# obj = -138.470097, rho = 0.860436
# nSV = 91, nBSV = 3
# *
# optimization finished, #iter = 433
# obj = -150.558481, rho = 0.597041
# nSV = 91, nBSV = 7
# *
# optimization finished, #iter = 282
# obj = -106.223361, rho = -0.443694
# nSV = 67, nBSV = 3
# *
# optimization finished, #iter = 363
# obj = -144.096917, rho = -0.119294
# nSV = 76, nBSV = 7
# *
# optimization finished, #iter = 455
# obj = -208.289825, rho = 0.329839
# nSV = 107, nBSV = 13
# *
# optimization finished, #iter = 351
# obj = -105.547119, rho = 0.280769
# nSV = 77, nBSV = 2
# .*
# optimization finished, #iter = 1729
# obj = -1865.829252, rho = 2.290155
# nSV = 328, nBSV = 154
# *
# optimization finished, #iter = 653
# obj = -299.630049, rho = -0.567609
# nSV = 135, nBSV = 14
# *
# optimization finished, #iter = 644
# obj = -212.261911, rho = 0.149966
# nSV = 142, nBSV = 5
# *
# optimization finished, #iter = 804
# obj = -221.253173, rho = -0.295096
# nSV = 154, nBSV = 4
# *
# optimization finished, #iter = 740
# obj = -234.145593, rho = -1.947757
# nSV = 154, nBSV = 5
# *
# optimization finished, #iter = 485
# obj = -162.499901, rho = -1.161953
# nSV = 108, nBSV = 6
# *
# optimization finished, #iter = 752
# obj = -236.981938, rho = -0.101775
# nSV = 164, nBSV = 4
# *
# optimization finished, #iter = 482
# obj = -141.679856, rho = -0.137842
# nSV = 111, nBSV = 2
# .*.*
# optimization finished, #iter = 2705
# obj = -1499.218212, rho = 4.351696
# nSV = 452, nBSV = 102
# *
# optimization finished, #iter = 284
# obj = -72.812552, rho = 0.241028
# nSV = 73, nBSV = 0
# *
# optimization finished, #iter = 842
# obj = -322.032040, rho = 0.853887
# nSV = 161, nBSV = 16
# *
# optimization finished, #iter = 383
# obj = -78.294910, rho = 0.154274
# nSV = 97, nBSV = 0
# *
# optimization finished, #iter = 566
# obj = -203.582912, rho = -0.309921
# nSV = 116, nBSV = 8
# *
# optimization finished, #iter = 698
# obj = -268.082265, rho = 0.053612
# nSV = 145, nBSV = 11
# *
# optimization finished, #iter = 514
# obj = -228.344144, rho = 0.713338
# nSV = 121, nBSV = 11
# *.*
# optimization finished, #iter = 1229
# obj = -638.202960, rho = 4.084349
# nSV = 244, nBSV = 33
# *
# optimization finished, #iter = 538
# obj = -186.996945, rho = -0.137977
# nSV = 129, nBSV = 5
# *
# optimization finished, #iter = 405
# obj = -149.382207, rho = -1.105684
# nSV = 97, nBSV = 5
# *
# optimization finished, #iter = 517
# obj = -170.175817, rho = -0.253085
# nSV = 106, nBSV = 6
# *
# optimization finished, #iter = 624
# obj = -251.505169, rho = 0.270509
# nSV = 142, nBSV = 13
# *
# optimization finished, #iter = 801
# obj = -380.178098, rho = -1.517991
# nSV = 162, nBSV = 20
# .*.*
# optimization finished, #iter = 2231
# obj = -1478.078117, rho = 2.174885
# nSV = 415, nBSV = 118
# *
# optimization finished, #iter = 555
# obj = -230.950015, rho = -1.382634
# nSV = 126, nBSV = 9
# *
# optimization finished, #iter = 448
# obj = -139.389628, rho = -0.188780
# nSV = 99, nBSV = 3
# *
# optimization finished, #iter = 814
# obj = -387.935220, rho = -0.670320
# nSV = 183, nBSV = 17
# *
# optimization finished, #iter = 569
# obj = -178.877222, rho = -0.288327
# nSV = 122, nBSV = 5
# .*.*
# optimization finished, #iter = 2491
# obj = -1412.032311, rho = 3.124987
# nSV = 433, nBSV = 92
# *
# optimization finished, #iter = 189
# obj = -50.422522, rho = 0.055567
# nSV = 58, nBSV = 0
# *
# optimization finished, #iter = 545
# obj = -186.742813, rho = 0.484712
# nSV = 114, nBSV = 5
# *
# optimization finished, #iter = 216
# obj = -67.853785, rho = 0.203881
# nSV = 61, nBSV = 0
# .*
# optimization finished, #iter = 1604
# obj = -966.865068, rho = 4.792669
# nSV = 308, nBSV = 72
# *
# optimization finished, #iter = 530
# obj = -154.495968, rho = 0.860995
# nSV = 112, nBSV = 3
# *
# optimization finished, #iter = 945
# obj = -588.771058, rho = -0.341474
# nSV = 187, nBSV = 41
# *
# optimization finished, #iter = 996
# obj = -591.641442, rho = 2.995052
# nSV = 208, nBSV = 38
# *
# optimization finished, #iter = 827
# obj = -353.087724, rho = -0.049621
# nSV = 153, nBSV = 12
# .*.*
# optimization finished, #iter = 2704
# obj = -1434.784166, rho = 6.464415
# nSV = 457, nBSV = 98
# .*
# optimization finished, #iter = 1577
# obj = -1016.024278, rho = 3.379255
# nSV = 320, nBSV = 77
# Total nSV = 3058
# [CV 1/1; 7/9] END ............C=10, gamma=0.001;, score=0.896 total time=  13.0s
# [CV 1/1; 8/9] START C=10, gamma=0.01............................................
# [LibSVM]*
# optimization finished, #iter = 521
# obj = -29.962561, rho = -0.628137
# nSV = 294, nBSV = 0
# *
# optimization finished, #iter = 983
# obj = -97.751772, rho = 0.270796
# nSV = 593, nBSV = 0
# *
# optimization finished, #iter = 805
# obj = -79.394534, rho = 0.049173
# nSV = 490, nBSV = 0
# *
# optimization finished, #iter = 857
# obj = -74.183904, rho = 0.061445
# nSV = 512, nBSV = 0
# *
# optimization finished, #iter = 959
# obj = -95.451195, rho = 0.167172
# nSV = 564, nBSV = 0
# *
# optimization finished, #iter = 925
# obj = -89.766062, rho = -0.035145
# nSV = 526, nBSV = 0
# *
# optimization finished, #iter = 710
# obj = -60.680401, rho = -0.143763
# nSV = 423, nBSV = 0
# *
# optimization finished, #iter = 916
# obj = -88.320867, rho = 0.190540
# nSV = 553, nBSV = 0
# *
# optimization finished, #iter = 749
# obj = -67.224919, rho = -0.053567
# nSV = 452, nBSV = 0
# .*
# optimization finished, #iter = 1617
# obj = -170.737867, rho = 0.730357
# nSV = 962, nBSV = 0
# *
# optimization finished, #iter = 616
# obj = -39.764060, rho = 0.832207
# nSV = 371, nBSV = 0
# *
# optimization finished, #iter = 530
# obj = -35.463698, rho = 0.700225
# nSV = 314, nBSV = 0
# *
# optimization finished, #iter = 668
# obj = -41.967128, rho = 0.753065
# nSV = 357, nBSV = 0
# *
# optimization finished, #iter = 634
# obj = -38.235656, rho = 0.756509
# nSV = 378, nBSV = 0
# *
# optimization finished, #iter = 546
# obj = -36.978706, rho = 0.633506
# nSV = 306, nBSV = 0
# *
# optimization finished, #iter = 560
# obj = -45.825926, rho = 0.599846
# nSV = 280, nBSV = 0
# *
# optimization finished, #iter = 595
# obj = -44.285341, rho = 0.810888
# nSV = 346, nBSV = 0
# *
# optimization finished, #iter = 569
# obj = -39.667284, rho = 0.653069
# nSV = 309, nBSV = 0
# .*
# optimization finished, #iter = 1764
# obj = -742.037191, rho = 1.031014
# nSV = 536, nBSV = 39
# *.*
# optimization finished, #iter = 1025
# obj = -118.558593, rho = -0.236649
# nSV = 638, nBSV = 0
# *.*
# optimization finished, #iter = 1023
# obj = -101.132119, rho = -0.218887
# nSV = 632, nBSV = 0
# *.*
# optimization finished, #iter = 1092
# obj = -113.959924, rho = -0.135122
# nSV = 671, nBSV = 0
# *.*
# optimization finished, #iter = 1032
# obj = -102.146026, rho = -0.345029
# nSV = 611, nBSV = 0
# *
# optimization finished, #iter = 998
# obj = -92.588463, rho = -0.421860
# nSV = 584, nBSV = 0
# *.*
# optimization finished, #iter = 1128
# obj = -130.279300, rho = -0.079598
# nSV = 695, nBSV = 0
# *
# optimization finished, #iter = 944
# obj = -90.647580, rho = -0.314184
# nSV = 580, nBSV = 0
# .*
# optimization finished, #iter = 1989
# obj = -275.844466, rho = 0.537111
# nSV = 1178, nBSV = 0
# *
# optimization finished, #iter = 855
# obj = -77.181607, rho = 0.009924
# nSV = 537, nBSV = 0
# *.*
# optimization finished, #iter = 993
# obj = -120.209559, rho = 0.092941
# nSV = 617, nBSV = 0
# *
# optimization finished, #iter = 797
# obj = -75.896981, rho = -0.095945
# nSV = 493, nBSV = 0
# *
# optimization finished, #iter = 855
# obj = -84.963988, rho = -0.194434
# nSV = 504, nBSV = 0
# *.*
# optimization finished, #iter = 1017
# obj = -121.523577, rho = 0.164594
# nSV = 619, nBSV = 0
# *
# optimization finished, #iter = 913
# obj = -91.935155, rho = -0.086542
# nSV = 536, nBSV = 0
# .*
# optimization finished, #iter = 1478
# obj = -165.752148, rho = 0.671197
# nSV = 934, nBSV = 0
# *.*
# optimization finished, #iter = 1045
# obj = -97.404072, rho = 0.082459
# nSV = 639, nBSV = 0
# *
# optimization finished, #iter = 864
# obj = -81.183376, rho = -0.113711
# nSV = 531, nBSV = 0
# *
# optimization finished, #iter = 882
# obj = -90.207889, rho = -0.244480
# nSV = 507, nBSV = 0
# *.*
# optimization finished, #iter = 1032
# obj = -109.531316, rho = 0.145787
# nSV = 619, nBSV = 0
# *.*
# optimization finished, #iter = 1131
# obj = -131.182040, rho = -0.158651
# nSV = 628, nBSV = 0
# .*
# optimization finished, #iter = 1930
# obj = -245.865844, rho = 0.710933
# nSV = 1120, nBSV = 0
# *
# optimization finished, #iter = 936
# obj = -99.260000, rho = -0.219130
# nSV = 569, nBSV = 0
# *
# optimization finished, #iter = 902
# obj = -79.513776, rho = -0.298166
# nSV = 541, nBSV = 0
# *.*
# optimization finished, #iter = 1110
# obj = -135.390534, rho = 0.044194
# nSV = 670, nBSV = 0
# *
# optimization finished, #iter = 957
# obj = -93.696236, rho = -0.211815
# nSV = 579, nBSV = 0
# .*.*
# optimization finished, #iter = 2004
# obj = -249.924096, rho = 0.634513
# nSV = 1178, nBSV = 0
# *
# optimization finished, #iter = 700
# obj = -57.405232, rho = -0.095436
# nSV = 423, nBSV = 0
# *
# optimization finished, #iter = 893
# obj = -99.477336, rho = 0.246423
# nSV = 541, nBSV = 0
# *
# optimization finished, #iter = 729
# obj = -64.513458, rho = -0.003770
# nSV = 450, nBSV = 0
# .*
# optimization finished, #iter = 1628
# obj = -182.439353, rho = 0.775975
# nSV = 983, nBSV = 0
# *
# optimization finished, #iter = 905
# obj = -88.994033, rho = 0.362534
# nSV = 547, nBSV = 0
# *.*
# optimization finished, #iter = 1046
# obj = -134.054217, rho = 0.169779
# nSV = 564, nBSV = 0
# .*
# optimization finished, #iter = 1498
# obj = -137.805343, rho = 0.790846
# nSV = 896, nBSV = 0
# *.*
# optimization finished, #iter = 1065
# obj = -122.525701, rho = -0.286621
# nSV = 619, nBSV = 0
# .*
# optimization finished, #iter = 1977
# obj = -250.123944, rho = 0.638618
# nSV = 1173, nBSV = 0
# .*
# optimization finished, #iter = 1789
# obj = -205.657061, rho = 0.756524
# nSV = 1031, nBSV = 0
# Total nSV = 4685
# [CV 1/1; 8/9] END .............C=10, gamma=0.01;, score=0.890 total time=  29.6s
# [CV 1/1; 9/9] START C=10, gamma=0.1.............................................
# [LibSVM].*.*
# optimization finished, #iter = 2014
# obj = -359.360406, rho = -0.295754
# nSV = 994, nBSV = 0
# .*
# optimization finished, #iter = 1865
# obj = -512.618312, rho = 0.004599
# nSV = 1026, nBSV = 0
# .*.*
# optimization finished, #iter = 2889
# obj = -491.985810, rho = -0.035835
# nSV = 986, nBSV = 0
# .*.*
# optimization finished, #iter = 2327
# obj = -495.116128, rho = -0.029701
# nSV = 992, nBSV = 0
# *..*
# optimization finished, #iter = 2017
# obj = -509.110583, rho = -0.002275
# nSV = 1019, nBSV = 0
# .*.*
# optimization finished, #iter = 2567
# obj = -497.602125, rho = -0.024829
# nSV = 997, nBSV = 0
# .*.*
# optimization finished, #iter = 2074
# obj = -505.177896, rho = -0.009983
# nSV = 1015, nBSV = 0
# .*.*
# optimization finished, #iter = 2542
# obj = -505.054733, rho = -0.010224
# nSV = 1011, nBSV = 0
# *.*
# optimization finished, #iter = 1654
# obj = -509.236066, rho = -0.002029
# nSV = 1020, nBSV = 0
# ...*.*
# optimization finished, #iter = 4256
# obj = -674.000451, rho = 0.320864
# nSV = 1511, nBSV = 0
# .*.*
# optimization finished, #iter = 2017
# obj = -360.522802, rho = 0.299960
# nSV = 998, nBSV = 0
# .*
# optimization finished, #iter = 1766
# obj = -350.194073, rho = 0.262689
# nSV = 958, nBSV = 0
# .*
# optimization finished, #iter = 1641
# obj = -351.777964, rho = 0.268407
# nSV = 964, nBSV = 0
# .*.*
# optimization finished, #iter = 2018
# obj = -358.784220, rho = 0.293698
# nSV = 991, nBSV = 0
# .*
# optimization finished, #iter = 1725
# obj = -353.030490, rho = 0.272912
# nSV = 969, nBSV = 0
# .*
# optimization finished, #iter = 1936
# obj = -356.854776, rho = 0.286645
# nSV = 987, nBSV = 0
# .*
# optimization finished, #iter = 1979
# obj = -356.765220, rho = 0.286404
# nSV = 983, nBSV = 0
# .*
# optimization finished, #iter = 1972
# obj = -358.854001, rho = 0.293932
# nSV = 992, nBSV = 0
# ..*
# optimization finished, #iter = 2968
# obj = -474.965832, rho = 0.568356
# nSV = 1492, nBSV = 0
# ..*
# optimization finished, #iter = 2945
# obj = -494.167074, rho = -0.040428
# nSV = 990, nBSV = 0
# .*.*
# optimization finished, #iter = 2825
# obj = -497.325325, rho = -0.034295
# nSV = 996, nBSV = 0
# .*.*
# optimization finished, #iter = 2282
# obj = -511.446718, rho = -0.006874
# nSV = 1023, nBSV = 0
# .*.*
# optimization finished, #iter = 2436
# obj = -499.833560, rho = -0.029425
# nSV = 1001, nBSV = 0
# .*.*
# optimization finished, #iter = 2122
# obj = -507.478188, rho = -0.014580
# nSV = 1019, nBSV = 0
# .*.*
# optimization finished, #iter = 2270
# obj = -507.353689, rho = -0.014822
# nSV = 1015, nBSV = 0
# .*.*
# optimization finished, #iter = 2079
# obj = -511.573358, rho = -0.006628
# nSV = 1024, nBSV = 0
# ...*.*
# optimization finished, #iter = 4684
# obj = -678.099049, rho = 0.316730
# nSV = 1515, nBSV = 0
# .*.*
# optimization finished, #iter = 2005
# obj = -477.882121, rho = 0.006141
# nSV = 956, nBSV = 0
# .*.*
# optimization finished, #iter = 2520
# obj = -490.906523, rho = 0.033563
# nSV = 983, nBSV = 0
# .*.*
# optimization finished, #iter = 2073
# obj = -480.197662, rho = 0.011016
# nSV = 961, nBSV = 0
# .*.*
# optimization finished, #iter = 2283
# obj = -487.249093, rho = 0.025862
# nSV = 979, nBSV = 0
# .*.*
# optimization finished, #iter = 2600
# obj = -487.134466, rho = 0.025621
# nSV = 975, nBSV = 0
# .*.*
# optimization finished, #iter = 2609
# obj = -491.023223, rho = 0.033808
# nSV = 984, nBSV = 0
# ...*.*
# optimization finished, #iter = 4888
# obj = -642.458072, rho = 0.352642
# nSV = 1475, nBSV = 0
# .*.*
# optimization finished, #iter = 2207
# obj = -494.023057, rho = 0.027427
# nSV = 989, nBSV = 0
# .*.*
# optimization finished, #iter = 2067
# obj = -483.179251, rho = 0.004876
# nSV = 967, nBSV = 0
# .*.*
# optimization finished, #iter = 2346
# obj = -490.319518, rho = 0.019724
# nSV = 985, nBSV = 0
# .*.*
# optimization finished, #iter = 2231
# obj = -490.203147, rho = 0.019483
# nSV = 981, nBSV = 0
# .*.*
# optimization finished, #iter = 2671
# obj = -494.145314, rho = 0.027673
# nSV = 990, nBSV = 0
# ...*.*
# optimization finished, #iter = 4415
# obj = -647.810843, rho = 0.347255
# nSV = 1481, nBSV = 0
# .*.*
# optimization finished, #iter = 2704
# obj = -496.498025, rho = -0.022555
# nSV = 994, nBSV = 0
# .*
# optimization finished, #iter = 1631
# obj = -504.039995, rho = -0.007707
# nSV = 1012, nBSV = 0
# .*
# optimization finished, #iter = 1624
# obj = -503.917361, rho = -0.007949
# nSV = 1008, nBSV = 0
# *
# optimization finished, #iter = 970
# obj = -508.079835, rho = 0.000246
# nSV = 1017, nBSV = 0
# ...*..*
# optimization finished, #iter = 5139
# obj = -671.974100, rho = 0.322901
# nSV = 1508, nBSV = 0
# .*.*
# optimization finished, #iter = 2266
# obj = -492.757051, rho = 0.014851
# nSV = 990, nBSV = 0
# .*.*
# optimization finished, #iter = 2266
# obj = -492.639891, rho = 0.014609
# nSV = 986, nBSV = 0
# .*.*
# optimization finished, #iter = 2144
# obj = -496.617387, rho = 0.022801
# nSV = 995, nBSV = 0
# ...*.*
# optimization finished, #iter = 4314
# obj = -652.069514, rho = 0.342959
# nSV = 1486, nBSV = 0
# *.*
# optimization finished, #iter = 1008
# obj = -500.064226, rho = -0.000242
# nSV = 1004, nBSV = 0
# .*
# optimization finished, #iter = 1666
# obj = -504.170303, rho = 0.007954
# nSV = 1013, nBSV = 0
# ...*.*
# optimization finished, #iter = 4040
# obj = -665.143025, rho = 0.329789
# nSV = 1504, nBSV = 0
# .*.*
# optimization finished, #iter = 2360
# obj = -504.040488, rho = 0.008195
# nSV = 1009, nBSV = 0
# ...*.*
# optimization finished, #iter = 4794
# obj = -664.926213, rho = 0.330003
# nSV = 1500, nBSV = 0
# ...*.*
# optimization finished, #iter = 4742
# obj = -672.215858, rho = 0.322692
# nSV = 1509, nBSV = 0
# Total nSV = 5983
# [CV 1/1; 9/9] END ..............C=10, gamma=0.1;, score=0.213 total time=  41.5s
# [LibSVM]*
# optimization finished, #iter = 304
# obj = -103.096329, rho = -0.151052
# nSV = 68, nBSV = 3
# *
# optimization finished, #iter = 892
# obj = -238.764038, rho = 0.901182
# nSV = 165, nBSV = 3
# *
# optimization finished, #iter = 658
# obj = -188.813323, rho = -0.221237
# nSV = 139, nBSV = 3
# *
# optimization finished, #iter = 606
# obj = -164.693981, rho = 0.713016
# nSV = 131, nBSV = 3
# *
# optimization finished, #iter = 963
# obj = -307.186112, rho = 0.982165
# nSV = 182, nBSV = 9
# *
# optimization finished, #iter = 690
# obj = -296.822818, rho = -0.228217
# nSV = 146, nBSV = 17
# *
# optimization finished, #iter = 372
# obj = -97.222447, rho = -0.167866
# nSV = 92, nBSV = 0
# *
# optimization finished, #iter = 652
# obj = -246.025921, rho = 0.293409
# nSV = 151, nBSV = 8
# *
# optimization finished, #iter = 484
# obj = -134.772854, rho = -0.549892
# nSV = 108, nBSV = 0
# ..*.*
# optimization finished, #iter = 3126
# obj = -2216.483520, rho = 6.064300
# nSV = 549, nBSV = 185
# *
# optimization finished, #iter = 602
# obj = -257.706131, rho = 1.255546
# nSV = 122, nBSV = 12
# *
# optimization finished, #iter = 417
# obj = -171.554009, rho = 0.150597
# nSV = 91, nBSV = 6
# *
# optimization finished, #iter = 614
# obj = -212.860610, rho = 0.882235
# nSV = 117, nBSV = 9
# *
# optimization finished, #iter = 534
# obj = -252.011922, rho = 0.879255
# nSV = 124, nBSV = 15
# *
# optimization finished, #iter = 400
# obj = -179.718021, rho = -1.017759
# nSV = 89, nBSV = 8
# *
# optimization finished, #iter = 454
# obj = -201.191957, rho = -0.206731
# nSV = 90, nBSV = 12
# *
# optimization finished, #iter = 740
# obj = -327.773634, rho = -0.234138
# nSV = 139, nBSV = 21
# *
# optimization finished, #iter = 479
# obj = -147.820279, rho = 0.451494
# nSV = 91, nBSV = 4
# ..*.*
# optimization finished, #iter = 3096
# obj = -3476.052295, rho = 2.761368
# nSV = 573, nBSV = 319
# *.*
# optimization finished, #iter = 1091
# obj = -456.673536, rho = -0.494035
# nSV = 202, nBSV = 23
# *
# optimization finished, #iter = 899
# obj = -303.043296, rho = 0.476093
# nSV = 188, nBSV = 9
# *.*
# optimization finished, #iter = 1058
# obj = -305.154306, rho = -0.074877
# nSV = 212, nBSV = 7
# *.*
# optimization finished, #iter = 1135
# obj = -353.044222, rho = -2.272812
# nSV = 206, nBSV = 12
# *
# optimization finished, #iter = 654
# obj = -228.534634, rho = -1.018531
# nSV = 136, nBSV = 9
# *.*
# optimization finished, #iter = 1170
# obj = -428.780913, rho = -0.417901
# nSV = 226, nBSV = 16
# *
# optimization finished, #iter = 677
# obj = -200.173553, rho = -0.286433
# nSV = 136, nBSV = 5
# ..*..*
# optimization finished, #iter = 4207
# obj = -2415.697639, rho = 5.806448
# nSV = 685, nBSV = 190
# *
# optimization finished, #iter = 486
# obj = -132.633996, rho = 0.788595
# nSV = 115, nBSV = 2
# *.*
# optimization finished, #iter = 1167
# obj = -541.209407, rho = 1.453093
# nSV = 230, nBSV = 36
# *
# optimization finished, #iter = 462
# obj = -117.747844, rho = -0.122258
# nSV = 109, nBSV = 2
# *
# optimization finished, #iter = 840
# obj = -330.612865, rho = 0.477968
# nSV = 152, nBSV = 13
# *.*
# optimization finished, #iter = 1348
# obj = -571.539567, rho = -1.057751
# nSV = 250, nBSV = 30
# *
# optimization finished, #iter = 709
# obj = -350.688831, rho = 0.985754
# nSV = 159, nBSV = 19
# .*.*
# optimization finished, #iter = 2370
# obj = -1206.732499, rho = 5.213063
# nSV = 408, nBSV = 80
# *
# optimization finished, #iter = 869
# obj = -302.384029, rho = 0.045494
# nSV = 180, nBSV = 9
# *
# optimization finished, #iter = 662
# obj = -237.316450, rho = -1.769655
# nSV = 147, nBSV = 9
# *
# optimization finished, #iter = 711
# obj = -260.400667, rho = -0.024801
# nSV = 147, nBSV = 12
# *.*
# optimization finished, #iter = 1020
# obj = -360.688339, rho = -0.279567
# nSV = 197, nBSV = 17
# *.*
# optimization finished, #iter = 1286
# obj = -681.689611, rho = -2.048232
# nSV = 228, nBSV = 45
# ..*..*
# optimization finished, #iter = 4085
# obj = -2613.708114, rho = 1.640723
# nSV = 680, nBSV = 214
# *
# optimization finished, #iter = 821
# obj = -308.526641, rho = -2.150381
# nSV = 166, nBSV = 12
# *
# optimization finished, #iter = 616
# obj = -184.347962, rho = 0.063003
# nSV = 131, nBSV = 4
# .*
# optimization finished, #iter = 1584
# obj = -605.610314, rho = -1.723914
# nSV = 274, nBSV = 29
# *
# optimization finished, #iter = 784
# obj = -249.974003, rho = -0.286896
# nSV = 158, nBSV = 4
# ..*..*
# optimization finished, #iter = 4336
# obj = -2597.300118, rho = 2.904719
# nSV = 707, nBSV = 199
# *
# optimization finished, #iter = 261
# obj = -63.975537, rho = 0.078660
# nSV = 67, nBSV = 0
# *
# optimization finished, #iter = 678
# obj = -279.341896, rho = 0.868345
# nSV = 143, nBSV = 10
# *
# optimization finished, #iter = 336
# obj = -95.948365, rho = 0.405821
# nSV = 82, nBSV = 1
# .*.*
# optimization finished, #iter = 2938
# obj = -1760.832587, rho = 7.013590
# nSV = 492, nBSV = 134
# *
# optimization finished, #iter = 766
# obj = -221.257988, rho = 0.883099
# nSV = 154, nBSV = 6
# .*
# optimization finished, #iter = 1801
# obj = -907.541835, rho = -1.923988
# nSV = 294, nBSV = 68
# .*
# optimization finished, #iter = 1729
# obj = -1033.505951, rho = 3.117813
# nSV = 307, nBSV = 78
# *.*
# optimization finished, #iter = 1232
# obj = -519.409820, rho = 0.185080
# nSV = 222, nBSV = 25
# ...*.*
# optimization finished, #iter = 4776
# obj = -2611.469905, rho = 8.698068
# nSV = 750, nBSV = 211
# .*.*
# optimization finished, #iter = 2690
# obj = -1783.512191, rho = 4.129676
# nSV = 476, nBSV = 125
# Total nSV = 5082
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#              estimator=SVC(C=2.8, gamma=0.0073, verbose=1),
#              param_grid={'C': [0.1, 1, 10], 'gamma': [0.001, 0.01, 0.1]},
#              verbose=10)

# %% [markdown]
# Print the `best_score_` and `best_params_` attributes of the classifier to find the best score and parameters

# %%
# Print the best parameter and score of the classifier
print('The best parameter is {0}'.format(clf.best_params_))
print('The best score is {0:f}'.format(clf.best_score_))
# Out:
# The best parameter is {'C': 10, 'gamma': 0.001}
# The best score is 0.896000

# %% [markdown]
# Finally, print the CV test scores from `cv_results_['mean_test_score']`.

# %%
# Print the mean test score for each parameter value.
print('The mean test score for each parameter value is {0}'.format(clf.cv_results_['mean_test_score']))
# Out:
# The mean test score for each parameter value is [0.7815     0.599      0.16666667 0.86016667 0.88666667 0.20966667
#  0.896      0.8905     0.21266667]

# %% [markdown]
# ## Citations

# %% [markdown]
# Cohen, G., Afshar, S., Tapson, J., & van Schaik, A. (2017). EMNIST: an extension of MNIST to handwritten letters. Retrieved from http://arxiv.org/abs/1702.05373
